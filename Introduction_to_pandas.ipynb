# %% [markdown]
# # TensorFlow Developer Certificate in 2023: Zero to Mastery
#
# ### Section 17: Appendix pandas
#
# Try out pandas
#
# Section 17 of ZTM Tensorflow course

# %%
import pandas as pd

# %%
# 2 main data types

series = pd.Series(["Renault", "Volkswagen", "Mercedes"])
# series in this case could be called carbrands
# A Series is one single column of information

# %%
# Series = 1-dimensional

# %%
colours = pd.Series(["Green", "Blue", "Red"])

colours #does not need print()
# Out:
# 0    Green
# 1     Blue
# 2      Red
# dtype: object

# %%
# DataFrame = 2-dimensional

# %%
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
#give it a dictionary
#you can give the dataframe series objects as keys or values!!!

car_data
# Out:
#      Car make Colour
# 0     Renault  Green
# 1  Volkswagen   Blue
# 2    Mercedes    Red

# %%
#Usually you do not use Series to create a large dataframe
#you ofeten use a spread sheets with structured data

# %%
#import data from .csv
car_sales = pd.read_csv("car-sales.csv")

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# This image shows that:
#
# rows start at index 0 and colums start at index 1
#
# ![image.png](attachment:image.png)

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv")
#car_sales.to_execl (rarely used, cause csv works everywhere)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
#Trick: to get rid of the index also represented as a colums:
car_sales.to_csv("exported-car-sales.csv", index = False)
#add index = False
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
#like this it looks like we want it
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Data from URLs
#
# n some of the lectures, you'll notice .csv files being imported from file using something like:
#
# heart_disease = pd.read_csv("data/heart-disease.csv")
#
# This is helpful if you have the data downloaded to your computer or in the same directory as your notebook.
#
# But if you don't, another great feature of pandas is being able to import .csv files directly from a URL.
#
# For example, for the heart-disease.csv file, using the read_csv() function you can directly import it using the URL from the course GitHub repo:
#
# heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")
#
# Note: If you're using a link from GitHub, make sure it's in the "raw" format, by clicking the raw button.
# ![image.png](attachment:image.png)

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...
